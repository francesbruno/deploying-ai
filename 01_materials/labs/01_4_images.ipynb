# %% [markdown]
# ## Using an Image as Context
#
# There are several ways to interact with the client and use an image as context. They are discussed in the OpenAI platform [documentation](https://platform.openai.com/docs/guides/images-vision?format=base64-encoded#analyze-images). LMStudio inherits this behaviour. Keep in mind the model in use would need to support the task of interest. As we saw in the cell above, we could execute the following code but the model would fail at the specific task

# %% [markdown]
# First, we setup the tools.

# %%
# %load_ext dotenv
# %dotenv ../../05_src/.env
# %dotenv ../../05_src/.secrets

# %%
import sys
sys.path.append('../../05_src/')

# %%
import os
from IPython.display import display, Markdown
from utils.logger import get_logger
from utils.clients import get_client
MODEL = os.getenv('MODEL', 'gpt-4o-mini')
_logs = get_logger(__name__)
client = get_client()

# %% [markdown]
# We interrogate the model's capabilities. OpenAI model comparisons are [here](https://developers.openai.com/api/docs/models/compare).

# %%
response = client.responses.create(
    model = MODEL,
    input = 'Please give me two examples of tasks you can perform and tell me if you can classify images',
)

# %%
MODEL
# Out:
# 'gpt-4o-mini'

# %%
display(Markdown(response.output_text))
# Out:
# Sure! Here are two examples of tasks I can perform:
#
# 1. **Text Generation**: I can create written content on a variety of topics, including articles, stories, and reports.
#
# 2. **Answering Questions**: I can provide information and answer questions on a wide range of subjects, from history and science to pop culture and technology.
#
# As for image classification, while I cannot directly analyze images or classify them myself, I can discuss methods, techniques, and tools used for image classification if that's helpful!

# %% [markdown]
# Encode the image file.
#
# ![](./img/00_cat.jpg)

# %%
import base64
# Function to encode the image
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")
# Path to your image
image_path = "./img/00_cat.jpg"

# Getting the Base64 string
base64_image = encode_image(image_path)


response = client.responses.create(
    model=MODEL,
    input=[
        {
            "role": "user",
            "content": [
                { "type": "input_text", "text": "what's in this image?" },
                {
                    "type": "input_image",
                    "image_url": f"data:image/jpeg;base64,{base64_image}",
                },
            ],
        }
    ],
)

# %%
display(Markdown(response.output_text))
# Out:
# The image shows a tabby cat sitting on a wall. The cat has a distinctive striped coat and green eyes. In the background, there are some bare branches against a blue sky.
